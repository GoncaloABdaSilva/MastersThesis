# %%
import os
print(os.listdir('/kaggle/input/resampled-cracktree260/CrackTree260')) #should be ['val', 'train']
# Out:
# ['val', 'train']

# %%
import torch
import sys
import os

# Print PyTorch version
print(f"PyTorch Version: {torch.__version__}")

# Print Python version
print(f"Python Version: {sys.version}")

# Check for available GPUs
if torch.cuda.is_available():
    gpu_count = torch.cuda.device_count()
    print(f"{gpu_count} GPU(s) available:")
    for i in range(gpu_count):
        print(f"  GPU {i}: {torch.cuda.get_device_name(i)}")
    print(f"CUDA Version: {torch.version.cuda}")
else:
    print("GPU is not available.")

print("Number of CPUs in the system:", os.cpu_count())

os.environ['NO_ALBUMENTATIONS_UPDATE'] = '1'
# Out:
# PyTorch Version: 2.6.0+cu124
# Python Version: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# 2 GPU(s) available:
#   GPU 0: Tesla T4
#   GPU 1: Tesla T4
# CUDA Version: 12.4
# Number of CPUs in the system: 4

# %%
# !git clone https://github.com/facebookresearch/sam2.git
# %cd sam2
# !pip install -e .
#!pip install -e ".[notebooks]"

#os.rename("/kaggle/working/sam2", "/kaggle/working/sam2_repo")
# Out:
# Cloning into 'sam2'...
# remote: Enumerating objects: 1070, done.
# remote: Total 1070 (delta 0), reused 0 (delta 0), pack-reused 1070 (from 1)
# Receiving objects: 100% (1070/1070), 128.11 MiB | 44.88 MiB/s, done.
# Resolving deltas: 100% (380/380), done.
# /kaggle/working/sam2
# Obtaining file:///kaggle/working/sam2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 86.7 MB/s eta 0:00:00:00:010:01
# ...

# %%
# !wget -P /kaggle/working https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_small.pt
# Out:
# --2025-09-12 21:35:02--  https://dl.fbaipublicfiles.com/segment_anything_2/092824/sam2.1_hiera_small.pt
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.225.143.99, 13.225.143.54, 13.225.143.109, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.225.143.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 184416285 (176M) [application/vnd.snesdev-page-table]
# Saving to: ‘/kaggle/working/sam2.1_hiera_small.pt’
#
# sam2.1_hiera_small. 100%[===================>] 175.87M   273MB/s    in 0.6s
#
# 2025-09-12 21:35:03 (273 MB/s) - ‘/kaggle/working/sam2.1_hiera_small.pt’ saved [184416285/184416285]

# %%
import sys
sys.path.insert(1, '/kaggle/input/sam2-fine-tuning-code')
import utils
import dataset
import sam2_seg_wrapper
import train

# !python /kaggle/input/sam2-fine-tuning-code/train.py --epochs 3
# Out:
# [Patched] Loaded checkpoint from /kaggle/working/sam2.1_hiera_small.pt
# [Patched] Loaded checkpoint from /kaggle/working/sam2.1_hiera_small.pt
#
# [Epoch 0]
# 100%|█████████████████████████████| 200/200 [00:20<00:00,  9.97it/s, loss=0.588]
#
#
# Got 3939828/5242880 correct pixels, with TP = 12400, TN = 3927428, FP = 1281137, FN = 21915.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.7514625787734985
#
#         Precision = 0.009586119093000889
#
#         Recall = 0.36135801672935486
#
#         F1-Score = 0.01867678016424179
#
#         mIoU = 0.38014987111091614
#
#         Epoch loss = 0.6454038739204406
#
# [Epoch 1]
# 100%|█████████████████████████████| 200/200 [00:18<00:00, 10.94it/s, loss=0.573]
#
#
# Got 3909661/5242880 correct pixels, with TP = 13887, TN = 3895774, FP = 1312791, FN = 20428.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# ...
