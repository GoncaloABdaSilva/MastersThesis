# %%
import os
print(os.listdir('/kaggle/input/resampled-cracktree260/CrackTree260')) #should be ['val', 'train']
# Out:
# ['val', 'train']

# %%
import torch
import sys
import os

# Print PyTorch version
print(f"PyTorch Version: {torch.__version__}")

# Print Python version
print(f"Python Version: {sys.version}")

# Check for available GPUs
if torch.cuda.is_available():
    gpu_count = torch.cuda.device_count()
    print(f"{gpu_count} GPU(s) available:")
    for i in range(gpu_count):
        print(f"  GPU {i}: {torch.cuda.get_device_name(i)}")
    print(f"CUDA Version: {torch.version.cuda}")
else:
    print("GPU is not available.")

print("Number of CPUs in the system:", os.cpu_count())

os.environ['NO_ALBUMENTATIONS_UPDATE'] = '1'
# Out:
# PyTorch Version: 2.6.0+cu124
# Python Version: 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# 2 GPU(s) available:
#   GPU 0: Tesla T4
#   GPU 1: Tesla T4
# CUDA Version: 12.4
# Number of CPUs in the system: 4

# %%
import sys
sys.path.insert(1, '/kaggle/input/u-net-with-thincrack-features-code')
import utils
import dataset
import model
import train

# !python /kaggle/input/u-net-with-thincrack-features-code/train.py --epochs 200 --no-load_model #--load_model
# Out:
# GPU_ID/RANK: 1
# GPU_ID/RANK: 0
#
# [Epoch 0]
# 100%|█████████████████████████████████| 7/7 [00:23<00:00,  3.41s/it, loss=0.611]
# 100%|█████████████████████████████████| 7/7 [00:23<00:00,  3.41s/it, loss=0.637]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5206589/5242880 correct pixels, with TP = 26, TN = 5206563, FP = 2002, FN = 34289.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9930780529975891
#
#             Precision = 0.012820512987673283
#
#             Recall = 0.0007576861535198987
#
#             F1-Score = 0.0014308119425550103
#
#             mIoU = 0.4968969523906708
#
# [Epoch 1]
# 100%|█████████████████████████████████| 7/7 [00:18<00:00,  2.60s/it, loss=0.566]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.93s/it, loss=0.589]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5192568/5242880 correct pixels, with TP = 78, TN = 5192490, FP = 16075, FN = 34237.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9904037714004517
#
#             Precision = 0.004828824196010828
#
#             Recall = 0.002273058518767357
#
#             F1-Score = 0.0030910675413906574
#
#             mIoU = 0.4959757626056671
#
# [Epoch 2]
# 100%|█████████████████████████████████| 7/7 [00:18<00:00,  2.69s/it, loss=0.515]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.00s/it, loss=0.542]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5195200/5242880 correct pixels, with TP = 89, TN = 5195111, FP = 13454, FN = 34226.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.99090576171875
#
#             Precision = 0.006571660749614239
#
#             Recall = 0.0025936178863048553
#
#             F1-Score = 0.0037193363532423973
#
#             mIoU = 0.4963843524456024
#
# [Epoch 3]
# 100%|█████████████████████████████████| 7/7 [00:18<00:00,  2.66s/it, loss=0.463]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  3.00s/it, loss=0.491]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5206844/5242880 correct pixels, with TP = 218, TN = 5206626, FP = 1939, FN = 34097.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9931266903877258
#
#             Precision = 0.10106629878282547
#
#             Recall = 0.006352907046675682
#
#             F1-Score = 0.01195437554270029
#
#             mIoU = 0.49956977367401123
#
# [Epoch 4]
# 100%|█████████████████████████████████| 7/7 [00:18<00:00,  2.68s/it, loss=0.435]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.17s/it, loss=0.461]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 1795649/5242880 correct pixels, with TP = 30989, TN = 1764660, FP = 3443905, FN = 3326.
# => Saving best f1_score checkpoint.
#
# Metric scores: Accuracy = 0.34249287843704224
#
#             Precision = 0.008917969651520252
#
#             Recall = 0.9030744433403015
#
#             F1-Score = 0.017661530524492264
#
#             mIoU = 0.17374643683433533
#
# [Epoch 5]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.91s/it, loss=0.431]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.74s/it, loss=0.399]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5134105/5242880 correct pixels, with TP = 12804, TN = 5121301, FP = 87264, FN = 21511.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.979252815246582
#
#             Precision = 0.12795299291610718
#
#             Recall = 0.37313127517700195
#
#             F1-Score = 0.19055981934070587
#
#             mIoU = 0.5422581434249878
#
# [Epoch 6]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.71s/it, loss=0.375]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.18s/it, loss=0.411]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5142332/5242880 correct pixels, with TP = 17537, TN = 5124795, FP = 83770, FN = 16778.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9808220267295837
#
#             Precision = 0.17310748994350433
#
#             Recall = 0.5110592842102051
#
#             F1-Score = 0.2586158514022827
#
#             mIoU = 0.5646346807479858
#
# [Epoch 7]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.82s/it, loss=0.362]
# 100%|█████████████████████████████████| 7/7 [00:23<00:00,  3.30s/it, loss=0.389]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5097258/5242880 correct pixels, with TP = 21586, TN = 5075672, FP = 132893, FN = 12729.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9722248315811157
#
#             Precision = 0.1397342085838318
#
#             Recall = 0.6290543675422668
#
#             F1-Score = 0.22867251932621002
#
#             mIoU = 0.5506033301353455
#
# [Epoch 8]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.06s/it, loss=0.374]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.86s/it, loss=0.353]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5076487/5242880 correct pixels, with TP = 23086, TN = 5053401, FP = 155164, FN = 11229.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9682630896568298
#
#             Precision = 0.12951472401618958
#
#             Recall = 0.6727669835090637
#
#             F1-Score = 0.21721355617046356
#
#             mIoU = 0.5449810028076172
#
# [Epoch 9]
# 100%|██████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.34]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.09s/it, loss=0.366]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5056178/5242880 correct pixels, with TP = 24967, TN = 5031211, FP = 177354, FN = 9348.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.964389443397522
#
#             Precision = 0.1234029084444046
#
#             Recall = 0.7275826930999756
#
#             F1-Score = 0.21101607382297516
#
#             mIoU = 0.5410860180854797
#
# [Epoch 10]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.07s/it, loss=0.352]
# 100%|██████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.33]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5057842/5242880 correct pixels, with TP = 26334, TN = 5031508, FP = 177057, FN = 7981.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9647068381309509
#
#             Precision = 0.12947475910186768
#
#             Recall = 0.7674195170402527
#
#             F1-Score = 0.22156782448291779
#
#             mIoU = 0.5445573329925537
#
# [Epoch 11]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.10s/it, loss=0.349]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it, loss=0.325]
#
#
# Got 5115302/5242880 correct pixels, with TP = 22047, TN = 5093255, FP = 115310, FN = 12268.
# => Saving best loss checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9756664633750916
#
#             Precision = 0.16050875186920166
#
#             Recall = 0.6424887180328369
#
#             F1-Score = 0.2568502724170685
#
#             mIoU = 0.561456024646759
#
# [Epoch 12]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.07s/it, loss=0.346]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.93s/it, loss=0.315]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5080428/5242880 correct pixels, with TP = 22892, TN = 5057536, FP = 151029, FN = 11423.
#
# Metric scores: Accuracy = 0.9690147638320923
#
#             Precision = 0.13162298500537872
#
#             Recall = 0.6671134829521179
#
#             F1-Score = 0.21986591815948486
#
#             mIoU = 0.546194851398468
#
# [Epoch 13]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.81s/it, loss=0.316]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.85s/it, loss=0.335]
#
#
# Got 5030029/5242880 correct pixels, with TP = 24376, TN = 5005653, FP = 202912, FN = 9939.
#
# Metric scores: Accuracy = 0.9594019055366516
#
#             Precision = 0.10724719613790512
#
#             Recall = 0.7103598713874817
#
#             F1-Score = 0.1863587200641632
#
#             mIoU = 0.5309830904006958
#
# [Epoch 14]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.80s/it, loss=0.326]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.83s/it, loss=0.309]
#
#
# Got 5043694/5242880 correct pixels, with TP = 25297, TN = 5018397, FP = 190168, FN = 9018.
#
# Metric scores: Accuracy = 0.9620082974433899
#
#             Precision = 0.11740653961896896
#
#             Recall = 0.7371994853019714
#
#             F1-Score = 0.20255424082279205
#
#             mIoU = 0.5372570753097534
#
# [Epoch 15]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.86s/it, loss=0.315]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.329]
#
#
# Got 5055038/5242880 correct pixels, with TP = 25961, TN = 5029077, FP = 179488, FN = 8354.
# => Saving best loss checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9641720056533813
#
#             Precision = 0.12636226415634155
#
#             Recall = 0.756549596786499
#
#             F1-Score = 0.21655461192131042
#
#             mIoU = 0.5427092909812927
#
# [Epoch 16]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.94s/it, loss=0.329]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.86s/it, loss=0.305]
#
#
# Got 5097682/5242880 correct pixels, with TP = 25721, TN = 5071961, FP = 136604, FN = 8594.
# => Saving best f1_score checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]=> Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9723057150840759
#
#             Precision = 0.15845371782779694
#
#             Recall = 0.7495555877685547
#
#             F1-Score = 0.2616049647331238
#
#             mIoU = 0.5613278150558472
#
# [Epoch 17]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.16s/it, loss=0.317]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.297]
#
#
# Got 5083905/5242880 correct pixels, with TP = 26537, TN = 5057368, FP = 151197, FN = 7778.
#
# Metric scores: Accuracy = 0.9696779251098633
#
#             Precision = 0.14930738508701324
#
#             Recall = 0.7733352780342102
#
#             F1-Score = 0.25029119849205017
#
#             mIoU = 0.5562855005264282
#
# [Epoch 18]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.80s/it, loss=0.328]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.297]
#
#
# Got 5071877/5242880 correct pixels, with TP = 24136, TN = 5047741, FP = 160824, FN = 10179.
#
# Metric scores: Accuracy = 0.9673838019371033
#
#             Precision = 0.13049307465553284
#
#             Recall = 0.7033658623695374
#
#             F1-Score = 0.220143660902977
#
#             mIoU = 0.5454595685005188
#
# [Epoch 19]
# 100%|██████████████████████████████████| 7/7 [00:19<00:00,  2.82s/it, loss=0.29]
#
# => Saving checkpoint at epoch 20.
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.81s/it, loss=0.305]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 4967646/5242880 correct pixels, with TP = 25570, TN = 4942076, FP = 266489, FN = 8745.
#
# Metric scores: Accuracy = 0.9475032687187195
#
#             Precision = 0.0875508040189743
#
#             Recall = 0.7451551556587219
#
#             F1-Score = 0.15669140219688416
#
#             mIoU = 0.5161257982254028
#
# [Epoch 20]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.88s/it, loss=0.285]
# 100%|███████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.3]
#
#
# Got 5104453/5242880 correct pixels, with TP = 24853, TN = 5079600, FP = 128965, FN = 9462.
# => Saving best f1_score checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9735971689224243
#
#             Precision = 0.16157406568527222
#
#             Recall = 0.7242605090141296
#
#             F1-Score = 0.2642067074775696
#
#             mIoU = 0.5628411769866943
#
# [Epoch 21]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.94s/it, loss=0.292]
# 100%|██████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.28]
#
#
# Got 5142961/5242880 correct pixels, with TP = 22302, TN = 5120659, FP = 87906, FN = 12013.
# => Saving best miou checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]=> Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9809419512748718
#
#             Precision = 0.2023628056049347
#
#             Recall = 0.649919867515564
#
#             F1-Score = 0.3086290657520294
#
#             mIoU = 0.5816666483879089
#
# [Epoch 22]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.28s/it, loss=0.288]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.75s/it, loss=0.275]
#
#
# Got 5085238/5242880 correct pixels, with TP = 26282, TN = 5058956, FP = 149609, FN = 8033.
#
# Metric scores: Accuracy = 0.9699321985244751
#
#             Precision = 0.1494220793247223
#
#             Recall = 0.7659041285514832
#
#             F1-Score = 0.25005945563316345
#
#             mIoU = 0.5563383102416992
#
# [Epoch 23]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.86s/it, loss=0.282]
# 100%|██████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.27]
#
#
# Got 5089593/5242880 correct pixels, with TP = 26748, TN = 5062845, FP = 145720, FN = 7567.
#
# Metric scores: Accuracy = 0.9707628488540649
#
#             Precision = 0.15508964657783508
#
#             Recall = 0.779484212398529
#
#             F1-Score = 0.2587059736251831
#
#             mIoU = 0.5595920085906982
#
# [Epoch 24]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it, loss=0.265]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.86s/it, loss=0.277]
#
#
# Got 5098109/5242880 correct pixels, with TP = 27243, TN = 5070866, FP = 137699, FN = 7072.
# => Saving best loss checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9723871350288391
#
#             Precision = 0.16516715288162231
#
#             Recall = 0.7939093708992004
#
#             F1-Score = 0.27344584465026855
#
#             mIoU = 0.5653097629547119
#
# [Epoch 25]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.01s/it, loss=0.275]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.262]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5113716/5242880 correct pixels, with TP = 28094, TN = 5085622, FP = 122943, FN = 6221.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9753639101982117
#
#             Precision = 0.18600739538669586
#
#             Recall = 0.8187090158462524
#
#             F1-Score = 0.30314213037490845
#
#             mIoU = 0.57694011926651
#
# [Epoch 26]
# 100%|██████████████████████████████████| 7/7 [00:21<00:00,  3.14s/it, loss=0.27]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.94s/it, loss=0.257]
#
#
# Got 5119569/5242880 correct pixels, with TP = 27339, TN = 5092230, FP = 116335, FN = 6976.
# => Saving best loss checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9764803051948547
#
#             Precision = 0.19028495252132416
#
#             Recall = 0.7967069745063782
#
#             F1-Score = 0.30719876289367676
#
#             mIoU = 0.5789152979850769
#
# [Epoch 27]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.03s/it, loss=0.267]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.254]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5109848/5242880 correct pixels, with TP = 27622, TN = 5082226, FP = 126339, FN = 6693.
#
# Metric scores: Accuracy = 0.9746261835098267
#
#             Precision = 0.17940907180309296
#
#             Recall = 0.8049541115760803
#
#             F1-Score = 0.29342028498649597
#
#             mIoU = 0.5732132196426392
#
# [Epoch 28]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.99s/it, loss=0.261]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.96s/it, loss=0.249]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5117204/5242880 correct pixels, with TP = 27951, TN = 5089253, FP = 119312, FN = 6364.
#
# Metric scores: Accuracy = 0.9760292172431946
#
#             Precision = 0.18980327248573303
#
#             Recall = 0.814541757106781
#
#             F1-Score = 0.30786770582199097
#
#             mIoU = 0.5789207220077515
#
# [Epoch 29]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.245]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.97s/it, loss=0.257]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5146460/5242880 correct pixels, with TP = 27749, TN = 5118711, FP = 89854, FN = 6566.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9816093444824219
#
#             Precision = 0.2359548658132553
#
#             Recall = 0.8086550831794739
#
#             F1-Score = 0.3653154969215393
#
#             mIoU = 0.6024945974349976
#
# [Epoch 30]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.242]
# 100%|█████████████████████████████████| 7/7 [00:23<00:00,  3.33s/it, loss=0.254]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5159030/5242880 correct pixels, with TP = 27252, TN = 5131778, FP = 76787, FN = 7063.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9840068817138672
#
#             Precision = 0.26194024085998535
#
#             Recall = 0.7941716313362122
#
#             F1-Score = 0.39394596219062805
#
#             mIoU = 0.614605724811554
#
# [Epoch 31]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.86s/it, loss=0.238]
# 100%|█████████████████████████████████| 7/7 [00:23<00:00,  3.37s/it, loss=0.249]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5143172/5242880 correct pixels, with TP = 28893, TN = 5114279, FP = 94286, FN = 5422.
#
# Metric scores: Accuracy = 0.98098224401474
#
#             Precision = 0.23456108570098877
#
#             Recall = 0.8419932723045349
#
#             F1-Score = 0.3669092059135437
#
#             mIoU = 0.6027742624282837
#
# [Epoch 32]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.246]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.88s/it, loss=0.236]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5146607/5242880 correct pixels, with TP = 28315, TN = 5118292, FP = 90273, FN = 6000.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9816374182701111
#
#             Precision = 0.2387678325176239
#
#             Recall = 0.8251493573188782
#
#             F1-Score = 0.37036553025245667
#
#             mIoU = 0.6044033765792847
#
# [Epoch 33]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.85s/it, loss=0.232]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.07s/it, loss=0.243]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5128758/5242880 correct pixels, with TP = 29575, TN = 5099183, FP = 109382, FN = 4740.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9782329797744751
#
#             Precision = 0.2128356248140335
#
#             Recall = 0.8618679642677307
#
#             F1-Score = 0.3413707911968231
#
#             mIoU = 0.5919622182846069
#
# [Epoch 34]
# 100%|██████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.23]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.12s/it, loss=0.239]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5154920/5242880 correct pixels, with TP = 27799, TN = 5127121, FP = 81444, FN = 6516.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9832229614257812
#
#             Precision = 0.2544693946838379
#
#             Recall = 0.8101121783256531
#
#             F1-Score = 0.387285977602005
#
#             mIoU = 0.6116394996643066
#
# [Epoch 35]
# 100%|██████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.23]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.15s/it, loss=0.238]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5128655/5242880 correct pixels, with TP = 30325, TN = 5098330, FP = 110235, FN = 3990.
#
# Metric scores: Accuracy = 0.9782133102416992
#
#             Precision = 0.21574416756629944
#
#             Recall = 0.8837243318557739
#
#             F1-Score = 0.3468191623687744
#
#             mIoU = 0.5939378142356873
#
# [Epoch 36]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.228]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.94s/it, loss=0.235]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5119254/5242880 correct pixels, with TP = 30637, TN = 5088617, FP = 119948, FN = 3678.
#
# Metric scores: Accuracy = 0.9764202237129211
#
#             Precision = 0.2034531980752945
#
#             Recall = 0.8928165435791016
#
#             F1-Score = 0.3313899338245392
#
#             mIoU = 0.5874419808387756
#
# [Epoch 37]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.82s/it, loss=0.221]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.233]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5122473/5242880 correct pixels, with TP = 30556, TN = 5091917, FP = 116648, FN = 3759.
#
# Metric scores: Accuracy = 0.9770342111587524
#
#             Precision = 0.20757588744163513
#
#             Recall = 0.8904560804367065
#
#             F1-Score = 0.3366699814796448
#
#             mIoU = 0.5896533727645874
#
# [Epoch 38]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.94s/it, loss=0.232]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it, loss=0.219]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5151419/5242880 correct pixels, with TP = 29087, TN = 5122332, FP = 86233, FN = 5228.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9825552105903625
#
#             Precision = 0.25222858786582947
#
#             Recall = 0.8476467728614807
#
#             F1-Score = 0.3887726664543152
#
#             mIoU = 0.6118738055229187
#
# [Epoch 39]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.218]
#
# => Saving checkpoint at epoch 40.
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.12s/it, loss=0.226]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5147805/5242880 correct pixels, with TP = 28681, TN = 5119124, FP = 89441, FN = 5634.
#
# Metric scores: Accuracy = 0.9818658828735352
#
#             Precision = 0.2428082823753357
#
#             Recall = 0.8358152508735657
#
#             F1-Score = 0.3762997090816498
#
#             mIoU = 0.6067602634429932
#
# [Epoch 40]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.85s/it, loss=0.214]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.01s/it, loss=0.222]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5153116/5242880 correct pixels, with TP = 29655, TN = 5123461, FP = 85104, FN = 4660.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9828788638114929
#
#             Precision = 0.25841110944747925
#
#             Recall = 0.8641993403434753
#
#             F1-Score = 0.39785608649253845
#
#             mIoU = 0.6155543923377991
#
# [Epoch 41]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.83s/it, loss=0.211]
# 100%|██████████████████████████████████| 7/7 [00:24<00:00,  3.50s/it, loss=0.22]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5144172/5242880 correct pixels, with TP = 30420, TN = 5113752, FP = 94813, FN = 3895.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9811729788780212
#
#             Precision = 0.24290722608566284
#
#             Recall = 0.8864927887916565
#
#             F1-Score = 0.38132724165916443
#
#             mIoU = 0.6083216667175293
#
# [Epoch 42]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.13s/it, loss=0.217]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.94s/it, loss=0.207]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5151621/5242880 correct pixels, with TP = 30109, TN = 5121512, FP = 87053, FN = 4206.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9825937151908875
#
#             Precision = 0.2569860517978668
#
#             Recall = 0.877429723739624
#
#             F1-Score = 0.3975389003753662
#
#             mIoU = 0.6152867078781128
#
# [Epoch 43]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.204]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.17s/it, loss=0.214]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5139311/5242880 correct pixels, with TP = 30148, TN = 5109163, FP = 99402, FN = 4167.
#
# Metric scores: Accuracy = 0.9802457690238953
#
#             Precision = 0.2327132374048233
#
#             Recall = 0.8785662055015564
#
#             F1-Score = 0.36796143651008606
#
#             mIoU = 0.6027963757514954
#
# [Epoch 44]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.212]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.203]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5134056/5242880 correct pixels, with TP = 29897, TN = 5104159, FP = 104406, FN = 4418.
#
# Metric scores: Accuracy = 0.9792434573173523
#
#             Precision = 0.22260858118534088
#
#             Recall = 0.87125164270401
#
#             F1-Score = 0.35461220145225525
#
#             mIoU = 0.5973216891288757
#
# [Epoch 45]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.85s/it, loss=0.199]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.94s/it, loss=0.209]
#
#
# Got 5127564/5242880 correct pixels, with TP = 30094, TN = 5097470, FP = 111095, FN = 4221.
#
# Metric scores: Accuracy = 0.9780052304267883
#
#             Precision = 0.21314691007137299
#
#             Recall = 0.8769925832748413
#
#             F1-Score = 0.3429437577724457
#
#             mIoU = 0.592418909072876
#
# [Epoch 46]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.83s/it, loss=0.197]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.80s/it, loss=0.207]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5128119/5242880 correct pixels, with TP = 30102, TN = 5098017, FP = 110548, FN = 4213.
#
# Metric scores: Accuracy = 0.9781110882759094
#
#             Precision = 0.21402062475681305
#
#             Recall = 0.8772256970405579
#
#             F1-Score = 0.3440916836261749
#
#             mIoU = 0.5928905010223389
#
# [Epoch 47]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.91s/it, loss=0.195]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.94s/it, loss=0.204]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5134039/5242880 correct pixels, with TP = 30261, TN = 5103778, FP = 104787, FN = 4054.
#
# Metric scores: Accuracy = 0.9792402386665344
#
#             Precision = 0.22407588362693787
#
#             Recall = 0.8818592429161072
#
#             F1-Score = 0.35735076665878296
#
#             mIoU = 0.5983325839042664
#
# [Epoch 48]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.85s/it, loss=0.192]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it, loss=0.202]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5135457/5242880 correct pixels, with TP = 31100, TN = 5104357, FP = 104208, FN = 3215.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9795107245445251
#
#             Precision = 0.22984598577022552
#
#             Recall = 0.906309187412262
#
#             F1-Score = 0.3666955530643463
#
#             mIoU = 0.60194993019104
#
# [Epoch 49]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.04s/it, loss=0.199]
# 100%|██████████████████████████████████| 7/7 [00:19<00:00,  2.85s/it, loss=0.19]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5135124/5242880 correct pixels, with TP = 31118, TN = 5104006, FP = 104559, FN = 3197.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9794471859931946
#
#             Precision = 0.22935353219509125
#
#             Recall = 0.9068337678909302
#
#             F1-Score = 0.3661113381385803
#
#             mIoU = 0.6016990542411804
#
# [Epoch 50]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.88s/it, loss=0.188]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.10s/it, loss=0.197]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5135193/5242880 correct pixels, with TP = 30291, TN = 5104902, FP = 103663, FN = 4024.
#
# Metric scores: Accuracy = 0.9794603586196899
#
#             Precision = 0.22612985968589783
#
#             Recall = 0.8827335238456726
#
#             F1-Score = 0.3600306510925293
#
#             mIoU = 0.599437952041626
#
# [Epoch 51]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.86s/it, loss=0.185]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.88s/it, loss=0.195]
#
#
# Got 5132922/5242880 correct pixels, with TP = 30119, TN = 5102803, FP = 105762, FN = 4196.
#
# Metric scores: Accuracy = 0.9790272116661072
#
#             Precision = 0.2216571867465973
#
#             Recall = 0.8777211308479309
#
#             F1-Score = 0.3539331257343292
#
#             mIoU = 0.5969617366790771
#
# [Epoch 52]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.97s/it, loss=0.183]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.93s/it, loss=0.193]
#
#
# Got 5139741/5242880 correct pixels, with TP = 30394, TN = 5109347, FP = 99218, FN = 3921.
#
# Metric scores: Accuracy = 0.9803277850151062
#
#             Precision = 0.23449988663196564
#
#             Recall = 0.8857350945472717
#
#             F1-Score = 0.37082359194755554
#
#             mIoU = 0.6039136052131653
#
# [Epoch 53]
# 100%|██████████████████████████████████| 7/7 [00:20<00:00,  2.91s/it, loss=0.19]
# 100%|██████████████████████████████████| 7/7 [00:20<00:00,  2.97s/it, loss=0.18]
#
#
# Got 5146576/5242880 correct pixels, with TP = 29313, TN = 5117263, FP = 91302, FN = 5002.
#
# Metric scores: Accuracy = 0.9816314578056335
#
#             Precision = 0.24302947521209717
#
#             Recall = 0.8542328476905823
#
#             F1-Score = 0.3784031569957733
#
#             mIoU = 0.607440173625946
#
# [Epoch 54]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it, loss=0.189]
# 100%|██████████████████████████████████| 7/7 [00:20<00:00,  2.93s/it, loss=0.18]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5154531/5242880 correct pixels, with TP = 30353, TN = 5124178, FP = 84387, FN = 3962.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9831487536430359
#
#             Precision = 0.2645372152328491
#
#             Recall = 0.8845402598381042
#
#             F1-Score = 0.40727248787879944
#
#             mIoU = 0.6193791031837463
#
# [Epoch 55]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.177]
# 100%|█████████████████████████████████| 7/7 [00:24<00:00,  3.47s/it, loss=0.188]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5142551/5242880 correct pixels, with TP = 30129, TN = 5112422, FP = 96143, FN = 4186.
#
# Metric scores: Accuracy = 0.9808637499809265
#
#             Precision = 0.23860396444797516
#
#             Recall = 0.8780125379562378
#
#             F1-Score = 0.3752358555793762
#
#             mIoU = 0.6058505177497864
#
# [Epoch 56]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.95s/it, loss=0.176]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.01s/it, loss=0.185]
#
#
# Got 5159464/5242880 correct pixels, with TP = 29955, TN = 5129509, FP = 79056, FN = 4360.
# => Saving best miou checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]=> Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9840896725654602
#
#             Precision = 0.2747887969017029
#
#             Recall = 0.8729418516159058
#
#             F1-Score = 0.41799813508987427
#
#             mIoU = 0.6241096258163452
#
# [Epoch 57]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.173]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.28s/it, loss=0.183]
#
#
# Got 5148737/5242880 correct pixels, with TP = 30978, TN = 5117759, FP = 90806, FN = 3337.
# => Saving best loss checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9820436835289001
#
#             Precision = 0.254368394613266
#
#             Recall = 0.9027538895606995
#
#             F1-Score = 0.3969019651412964
#
#             mIoU = 0.6147606372833252
#
# [Epoch 58]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.172]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.01s/it, loss=0.181]
#
#
# Got 5138160/5242880 correct pixels, with TP = 31448, TN = 5106712, FP = 101853, FN = 2867.
#
# Metric scores: Accuracy = 0.9800262451171875
#
#             Precision = 0.23591721057891846
#
#             Recall = 0.916450560092926
#
#             F1-Score = 0.3752386271953583
#
#             mIoU = 0.6054278612136841
#
# [Epoch 59]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.81s/it, loss=0.179]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.86s/it, loss=0.169]
#
# => Saving checkpoint at epoch 60.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5157585/5242880 correct pixels, with TP = 30667, TN = 5126918, FP = 81647, FN = 3648.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9837312698364258
#
#             Precision = 0.27304700016975403
#
#             Recall = 0.893690824508667
#
#             F1-Score = 0.4182938039302826
#
#             mIoU = 0.6240464448928833
#
# [Epoch 60]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.167]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.28s/it, loss=0.177]
#
#
# Got 5153616/5242880 correct pixels, with TP = 31271, TN = 5122345, FP = 86220, FN = 3044.
# => Saving best loss checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9829742312431335
#
#             Precision = 0.26615655422210693
#
#             Recall = 0.9112924337387085
#
#             F1-Score = 0.4119863510131836
#
#             mIoU = 0.6211535334587097
#
# [Epoch 61]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.08s/it, loss=0.176]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.91s/it, loss=0.166]
#
#
# Got 5159125/5242880 correct pixels, with TP = 30101, TN = 5129024, FP = 79541, FN = 4214.
# => Saving best miou checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9840250015258789
#
#             Precision = 0.27453896403312683
#
#             Recall = 0.8771965503692627
#
#             F1-Score = 0.41819432377815247
#
#             mIoU = 0.6241552829742432
#
# [Epoch 62]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.88s/it, loss=0.164]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.01s/it, loss=0.174]
#
#
# Got 5168124/5242880 correct pixels, with TP = 30041, TN = 5138083, FP = 70482, FN = 4274.
# => Saving best miou checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]=> Saving best f1_score checkpoint.
#
# Metric scores: Accuracy = 0.9857414364814758
#
#             Precision = 0.2988470196723938
#
#             Recall = 0.8754480481147766
#
#             F1-Score = 0.44558656215667725
#
#             mIoU = 0.6361591219902039
#
# [Epoch 63]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.80s/it, loss=0.164]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.16s/it, loss=0.173]
#
#
# Got 5160767/5242880 correct pixels, with TP = 29819, TN = 5130948, FP = 77617, FN = 4496.
#
# Metric scores: Accuracy = 0.9843382239341736
#
#             Precision = 0.2775512933731079
#
#             Recall = 0.8689785599708557
#
#             F1-Score = 0.42072367668151855
#
#             mIoU = 0.6253256797790527
#
# [Epoch 64]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.91s/it, loss=0.162]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.171]
#
#
# Got 5162029/5242880 correct pixels, with TP = 28894, TN = 5133135, FP = 75430, FN = 5421.
#
# Metric scores: Accuracy = 0.9845789074897766
#
#             Precision = 0.27696406841278076
#
#             Recall = 0.8420224189758301
#
#             F1-Score = 0.41682353615760803
#
#             mIoU = 0.6238882541656494
#
# [Epoch 65]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.77s/it, loss=0.169]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.81s/it, loss=0.159]
#
#
# Got 5145189/5242880 correct pixels, with TP = 30768, TN = 5114421, FP = 94144, FN = 3547.
#
# Metric scores: Accuracy = 0.9813669323921204
#
#             Precision = 0.24631740152835846
#
#             Recall = 0.8966341018676758
#
#             F1-Score = 0.3864671289920807
#
#             mIoU = 0.6103864908218384
#
# [Epoch 66]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.167]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.93s/it, loss=0.159]
#
#
# Got 5167026/5242880 correct pixels, with TP = 30542, TN = 5136484, FP = 72081, FN = 3773.
# => Saving best miou checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]=> Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9855319857597351
#
#             Precision = 0.29761359095573425
#
#             Recall = 0.890048086643219
#
#             F1-Score = 0.44607049226760864
#
#             mIoU = 0.6362534761428833
#
# [Epoch 67]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.155]
# 100%|█████████████████████████████████| 7/7 [00:23<00:00,  3.40s/it, loss=0.164]
#
#
# Got 5162254/5242880 correct pixels, with TP = 30809, TN = 5131445, FP = 77120, FN = 3506.
# => Saving best loss checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9846218228340149
#
#             Precision = 0.28545618057250977
#
#             Recall = 0.8978289365768433
#
#             F1-Score = 0.4331852197647095
#
#             mIoU = 0.6305029988288879
#
# [Epoch 68]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.91s/it, loss=0.153]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.07s/it, loss=0.163]
#
#
# Got 5165474/5242880 correct pixels, with TP = 30500, TN = 5134974, FP = 73591, FN = 3815.
#
# Metric scores: Accuracy = 0.9852359890937805
#
#             Precision = 0.2930128574371338
#
#             Recall = 0.8888241052627563
#
#             F1-Score = 0.44073233008384705
#
#             mIoU = 0.6339014768600464
#
# [Epoch 69]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.161]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.95s/it, loss=0.151]
#
#
# Got 5160644/5242880 correct pixels, with TP = 30625, TN = 5130019, FP = 78546, FN = 3690.
#
# Metric scores: Accuracy = 0.9843147397041321
#
#             Precision = 0.2805232107639313
#
#             Recall = 0.8924668431282043
#
#             F1-Score = 0.4268709123134613
#
#             mIoU = 0.6277870535850525
#
# [Epoch 70]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.85s/it, loss=0.149]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.159]
#
#
# Got 5158959/5242880 correct pixels, with TP = 29746, TN = 5129213, FP = 79352, FN = 4569.
#
# Metric scores: Accuracy = 0.9839933514595032
#
#             Precision = 0.2726539373397827
#
#             Recall = 0.8668512105941772
#
#             F1-Score = 0.41482990980148315
#
#             mIoU = 0.6227980852127075
#
# [Epoch 71]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.97s/it, loss=0.148]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.86s/it, loss=0.157]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5171726/5242880 correct pixels, with TP = 30454, TN = 5141272, FP = 67293, FN = 3861.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.986428439617157
#
#             Precision = 0.31155943870544434
#
#             Recall = 0.8874835968017578
#
#             F1-Score = 0.46120762825012207
#
#             mIoU = 0.643034815788269
#
# [Epoch 72]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.78s/it, loss=0.146]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.28s/it, loss=0.156]
#
#
# Got 5157923/5242880 correct pixels, with TP = 30592, TN = 5127331, FP = 81234, FN = 3723.
#
# Metric scores: Accuracy = 0.9837957620620728
#
#             Precision = 0.2735678553581238
#
#             Recall = 0.8915051817893982
#
#             F1-Score = 0.4186641573905945
#
#             mIoU = 0.6242270469665527
#
# [Epoch 73]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.154]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it, loss=0.144]
#
#
# Got 5159343/5242880 correct pixels, with TP = 30308, TN = 5129035, FP = 79530, FN = 4007.
#
# Metric scores: Accuracy = 0.9840666055679321
#
#             Precision = 0.2759336531162262
#
#             Recall = 0.8832288980484009
#
#             F1-Score = 0.4204976558685303
#
#             mIoU = 0.6250977516174316
#
# [Epoch 74]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.88s/it, loss=0.143]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.153]
#
#
# Got 5156286/5242880 correct pixels, with TP = 30592, TN = 5125694, FP = 82871, FN = 3723.
#
# Metric scores: Accuracy = 0.9834834933280945
#
#             Precision = 0.2696209251880646
#
#             Recall = 0.8915051817893982
#
#             F1-Score = 0.4140264391899109
#
#             mIoU = 0.6222208142280579
#
# [Epoch 75]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.84s/it, loss=0.152]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.91s/it, loss=0.142]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5149882/5242880 correct pixels, with TP = 30446, TN = 5119436, FP = 89129, FN = 3869.
#
# Metric scores: Accuracy = 0.9822620749473572
#
#             Precision = 0.25461843609809875
#
#             Recall = 0.8872504830360413
#
#             F1-Score = 0.39568522572517395
#
#             mIoU = 0.6143983006477356
#
# [Epoch 76]
# 100%|██████████████████████████████████| 7/7 [00:20<00:00,  2.91s/it, loss=0.15]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.141]
#
#
# Got 5161992/5242880 correct pixels, with TP = 30202, TN = 5131790, FP = 76775, FN = 4113.
# => Saving best loss checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9845718741416931
#
#             Precision = 0.28232237696647644
#
#             Recall = 0.8801398873329163
#
#             F1-Score = 0.4275118112564087
#
#             mIoU = 0.6281760931015015
#
# [Epoch 77]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.95s/it, loss=0.138]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.11s/it, loss=0.148]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5175958/5242880 correct pixels, with TP = 30694, TN = 5145264, FP = 63301, FN = 3621.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9872356653213501
#
#             Precision = 0.3265492916107178
#
#             Recall = 0.8944776058197021
#
#             F1-Score = 0.47843503952026367
#
#             mIoU = 0.6507983207702637
#
# [Epoch 78]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.83s/it, loss=0.137]
# 100%|█████████████████████████████████| 7/7 [00:24<00:00,  3.45s/it, loss=0.146]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5166817/5242880 correct pixels, with TP = 30717, TN = 5136100, FP = 72465, FN = 3598.
#
# Metric scores: Accuracy = 0.9854921698570251
#
#             Precision = 0.2976972758769989
#
#             Recall = 0.8951479196548462
#
#             F1-Score = 0.4468024671077728
#
#             mIoU = 0.6365364193916321
#
# [Epoch 79]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.85s/it, loss=0.136]
#
# => Saving checkpoint at epoch 80.
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.146]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5165611/5242880 correct pixels, with TP = 30991, TN = 5134620, FP = 73945, FN = 3324.
#
# Metric scores: Accuracy = 0.9852620959281921
#
#             Precision = 0.2953324019908905
#
#             Recall = 0.9031327366828918
#
#             F1-Score = 0.44510990381240845
#
#             mIoU = 0.6357195377349854
#
# [Epoch 80]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.09s/it, loss=0.144]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.135]
#
#
# Got 5162783/5242880 correct pixels, with TP = 31027, TN = 5131756, FP = 76809, FN = 3288.
#
# Metric scores: Accuracy = 0.9847227334976196
#
#             Precision = 0.28772395849227905
#
#             Recall = 0.9041818380355835
#
#             F1-Score = 0.4365358054637909
#
#             mIoU = 0.6319211721420288
#
# [Epoch 81]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.143]
# 100%|█████████████████████████████████| 7/7 [00:20<00:00,  2.99s/it, loss=0.133]
#
#
# Got 5156715/5242880 correct pixels, with TP = 31514, TN = 5125201, FP = 83364, FN = 2801.
# => Saving best loss checkpoint.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
# Metric scores: Accuracy = 0.9835653305053711
#
#             Precision = 0.27432581782341003
#
#             Recall = 0.9183738827705383
#
#             F1-Score = 0.42245951294898987
#
#             mIoU = 0.6256311535835266
#
# [Epoch 82]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.10s/it, loss=0.142]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.00s/it, loss=0.132]
#
#
# Got 5162953/5242880 correct pixels, with TP = 30656, TN = 5132297, FP = 76268, FN = 3659.
#
# Metric scores: Accuracy = 0.9847551584243774
#
#             Precision = 0.2867083251476288
#
#             Recall = 0.8933702707290649
#
#             F1-Score = 0.43410107493400574
#
#             mIoU = 0.6309435367584229
#
# [Epoch 83]
# 100%|██████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.14]
# 100%|██████████████████████████████████| 7/7 [00:20<00:00,  2.97s/it, loss=0.13]
#
#
# Got 5167577/5242880 correct pixels, with TP = 30464, TN = 5137113, FP = 71452, FN = 3851.
#
# ...
#
#             Recall = 0.836806058883667
#
#             F1-Score = 0.6372897028923035
#
#             mIoU = 0.7306973934173584
#
# [Epoch 173]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it, loss=0.0509]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.11s/it, loss=0.0598]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5209456/5242880 correct pixels, with TP = 28755, TN = 5180701, FP = 27864, FN = 5560.
#
# Metric scores: Accuracy = 0.9936248660087585
#
#             Precision = 0.5078684091567993
#
#             Recall = 0.8379717469215393
#
#             F1-Score = 0.6324366927146912
#
#             mIoU = 0.7280224561691284
#
# [Epoch 174]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.0499]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.01s/it, loss=0.0578]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5210368/5242880 correct pixels, with TP = 28574, TN = 5181794, FP = 26771, FN = 5741.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
#
# Metric scores: Accuracy = 0.9937988519668579
#
#             Precision = 0.5162887573242188
#
#             Recall = 0.8326970934867859
#
#             F1-Score = 0.6373856663703918
#
#             mIoU = 0.7307658195495605
#
# [Epoch 175]
# 100%|████████████████████████████████| 7/7 [00:19<00:00,  2.82s/it, loss=0.0497]
# 100%|████████████████████████████████| 7/7 [00:22<00:00,  3.18s/it, loss=0.0577]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5211390/5242880 correct pixels, with TP = 28277, TN = 5183113, FP = 25452, FN = 6038.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
#
# Metric scores: Accuracy = 0.9939937591552734
#
#             Precision = 0.5262893438339233
#
#             Recall = 0.8240419626235962
#
#             F1-Score = 0.6423379182815552
#
#             mIoU = 0.7335408926010132
#
# [Epoch 176]
# 100%|████████████████████████████████| 7/7 [00:19<00:00,  2.85s/it, loss=0.0502]
# 100%|████████████████████████████████| 7/7 [00:23<00:00,  3.36s/it, loss=0.0586]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5210935/5242880 correct pixels, with TP = 28224, TN = 5182711, FP = 25854, FN = 6091.
#
# Metric scores: Accuracy = 0.9939069747924805
#
#             Precision = 0.5219128131866455
#
#             Recall = 0.8224974274635315
#
#             F1-Score = 0.638602614402771
#
#             mIoU = 0.731476366519928
#
# [Epoch 177]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.0492]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.97s/it, loss=0.0568]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5209484/5242880 correct pixels, with TP = 28199, TN = 5181285, FP = 27280, FN = 6116.
#
# Metric scores: Accuracy = 0.9936302304267883
#
#             Precision = 0.5082824230194092
#
#             Recall = 0.8217688798904419
#
#             F1-Score = 0.6280820369720459
#
#             mIoU = 0.7257044315338135
#
# [Epoch 178]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.0493]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.0583]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5208905/5242880 correct pixels, with TP = 28988, TN = 5179917, FP = 28648, FN = 5327.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9935197830200195
#
#             Precision = 0.5029495358467102
#
#             Recall = 0.8447617888450623
#
#             F1-Score = 0.6305097341537476
#
#             mIoU = 0.7269405722618103
#
# [Epoch 179]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.09s/it, loss=0.0561]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.0481]
#
# => Saving checkpoint at epoch 180.
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5210639/5242880 correct pixels, with TP = 28689, TN = 5181950, FP = 26615, FN = 5626.
#
# Metric scores: Accuracy = 0.9938505291938782
#
#             Precision = 0.5187509059906006
#
#             Recall = 0.8360483646392822
#
#             F1-Score = 0.6402437090873718
#
#             mIoU = 0.7323342561721802
#
# [Epoch 180]
# 100%|████████████████████████████████| 7/7 [00:19<00:00,  2.86s/it, loss=0.0475]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.09s/it, loss=0.0551]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5212377/5242880 correct pixels, with TP = 27356, TN = 5185021, FP = 23544, FN = 6959.
#
# Metric scores: Accuracy = 0.9941820502281189
#
#             Precision = 0.5374459624290466
#
#             Recall = 0.7972024083137512
#
#             F1-Score = 0.6420465707778931
#
#             mIoU = 0.7334780097007751
#
# [Epoch 181]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.02s/it, loss=0.0563]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it, loss=0.0479]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5211229/5242880 correct pixels, with TP = 28193, TN = 5183036, FP = 25529, FN = 6122.
#
# Metric scores: Accuracy = 0.9939630627632141
#
#             Precision = 0.524794340133667
#
#             Recall = 0.8215940594673157
#
#             F1-Score = 0.6404806971549988
#
#             mIoU = 0.7325193285942078
#
# [Epoch 182]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.00s/it, loss=0.0539]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.0467]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5209797/5242880 correct pixels, with TP = 28974, TN = 5180823, FP = 27742, FN = 5341.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.9936899542808533
#
#             Precision = 0.5108611583709717
#
#             Recall = 0.8443537950515747
#
#             F1-Score = 0.6365743279457092
#
#             mIoU = 0.7302740812301636
#
# [Epoch 183]
# 100%|████████████████████████████████| 7/7 [00:22<00:00,  3.17s/it, loss=0.0539]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.0464]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5209586/5242880 correct pixels, with TP = 28676, TN = 5180910, FP = 27655, FN = 5639.
#
# Metric scores: Accuracy = 0.9936496615409851
#
#             Precision = 0.5090625286102295
#
#             Recall = 0.8356695175170898
#
#             F1-Score = 0.6327030658721924
#
#             mIoU = 0.7281773686408997
#
# [Epoch 184]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.01s/it, loss=0.0535]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.86s/it, loss=0.0459]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5211355/5242880 correct pixels, with TP = 28241, TN = 5183114, FP = 25451, FN = 6074.
#
# Metric scores: Accuracy = 0.9939870834350586
#
#             Precision = 0.5259815454483032
#
#             Recall = 0.8229928612709045
#
#             F1-Score = 0.6417898535728455
#
#             mIoU = 0.7332403659820557
#
# [Epoch 185]
# 100%|█████████████████████████████████| 7/7 [00:21<00:00,  3.06s/it, loss=0.053]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.96s/it, loss=0.0451]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5212801/5242880 correct pixels, with TP = 28187, TN = 5184614, FP = 23951, FN = 6128.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
#
# Metric scores: Accuracy = 0.9942628741264343
#
#             Precision = 0.5406229496002197
#
#             Recall = 0.8214191794395447
#
#             F1-Score = 0.6520768404006958
#
#             mIoU = 0.7389979958534241
#
# [Epoch 186]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it, loss=0.0459]
# 100%|█████████████████████████████████| 7/7 [00:22<00:00,  3.26s/it, loss=0.053]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5212216/5242880 correct pixels, with TP = 28122, TN = 5184094, FP = 24471, FN = 6193.
#
# Metric scores: Accuracy = 0.9941512942314148
#
#             Precision = 0.5347099304199219
#
#             Recall = 0.8195250034332275
#
#             F1-Score = 0.6471671462059021
#
#             mIoU = 0.7362495064735413
#
# [Epoch 187]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.99s/it, loss=0.0448]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.08s/it, loss=0.0517]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5212001/5242880 correct pixels, with TP = 27807, TN = 5184194, FP = 24371, FN = 6508.
#
# Metric scores: Accuracy = 0.9941102862358093
#
#             Precision = 0.5329257249832153
#
#             Recall = 0.8103453516960144
#
#             F1-Score = 0.6429884433746338
#
#             mIoU = 0.7339528203010559
#
# [Epoch 188]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.09s/it, loss=0.0521]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.99s/it, loss=0.0448]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5211271/5242880 correct pixels, with TP = 28614, TN = 5182657, FP = 25908, FN = 5701.
#
# Metric scores: Accuracy = 0.993971049785614
#
#             Precision = 0.5248156785964966
#
#             Recall = 0.8338627219200134
#
#             F1-Score = 0.6441910266876221
#
#             mIoU = 0.7345360517501831
#
# [Epoch 189]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.94s/it, loss=0.0445]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.04s/it, loss=0.0521]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5212570/5242880 correct pixels, with TP = 27855, TN = 5184715, FP = 23850, FN = 6460.
#
# Metric scores: Accuracy = 0.9942188262939453
#
#             Precision = 0.5387293100357056
#
#             Recall = 0.8117441534996033
#
#             F1-Score = 0.6476401090621948
#
#             mIoU = 0.7365421056747437
#
# [Epoch 190]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.91s/it, loss=0.0433]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.02s/it, loss=0.0497]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5212818/5242880 correct pixels, with TP = 27622, TN = 5185196, FP = 23369, FN = 6693.
#
# Metric scores: Accuracy = 0.994266152381897
#
#             Precision = 0.541703462600708
#
#             Recall = 0.8049541115760803
#
#             F1-Score = 0.6475980877876282
#
#             mIoU = 0.7365429997444153
#
# [Epoch 191]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.03s/it, loss=0.0514]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.0437]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5211012/5242880 correct pixels, with TP = 28790, TN = 5182222, FP = 26343, FN = 5525.
# => Saving best loss checkpoint.
#
# Metric scores: Accuracy = 0.99392169713974
#
#             Precision = 0.5221917629241943
#
#             Recall = 0.8389917016029358
#
#             F1-Score = 0.6437259912490845
#
#             mIoU = 0.7342581748962402
#
# [Epoch 192]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.93s/it, loss=0.0422]
# 100%|████████████████████████████████| 7/7 [00:22<00:00,  3.15s/it, loss=0.0487]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5213608/5242880 correct pixels, with TP = 27670, TN = 5185938, FP = 22627, FN = 6645.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
#
# Metric scores: Accuracy = 0.9944168329238892
#
#             Precision = 0.5501322150230408
#
#             Recall = 0.8063529133796692
#
#             F1-Score = 0.6540443301200867
#
#             mIoU = 0.7401601076126099
#
# [Epoch 193]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.78s/it, loss=0.042]
# 100%|████████████████████████████████| 7/7 [00:22<00:00,  3.17s/it, loss=0.0487]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5213285/5242880 correct pixels, with TP = 28307, TN = 5184978, FP = 23587, FN = 6008.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
#
# Metric scores: Accuracy = 0.9943552017211914
#
#             Precision = 0.5454773306846619
#
#             Recall = 0.8249162435531616
#
#             F1-Score = 0.6567063927650452
#
#             mIoU = 0.7416011691093445
#
# [Epoch 194]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.90s/it, loss=0.0411]
# 100%|████████████████████████████████| 7/7 [00:22<00:00,  3.23s/it, loss=0.0477]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5214093/5242880 correct pixels, with TP = 27751, TN = 5186342, FP = 22223, FN = 6564.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
#
# Metric scores: Accuracy = 0.9945093393325806
#
#             Precision = 0.5553087592124939
#
#             Recall = 0.8087133765220642
#
#             F1-Score = 0.6584726572036743
#
#             mIoU = 0.7426590323448181
#
# [Epoch 195]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.0408]
# 100%|████████████████████████████████| 7/7 [00:22<00:00,  3.16s/it, loss=0.0473]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5214559/5242880 correct pixels, with TP = 27565, TN = 5186994, FP = 21571, FN = 6750.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
#
# Metric scores: Accuracy = 0.9945982098579407
#
#             Precision = 0.5609939694404602
#
#             Recall = 0.8032930493354797
#
#             F1-Score = 0.6606271862983704
#
#             mIoU = 0.7439029216766357
#
# [Epoch 196]
# 100%|█████████████████████████████████| 7/7 [00:19<00:00,  2.77s/it, loss=0.041]
# 100%|████████████████████████████████| 7/7 [00:22<00:00,  3.16s/it, loss=0.0476]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5213734/5242880 correct pixels, with TP = 26914, TN = 5186820, FP = 21745, FN = 7401.
#
# Metric scores: Accuracy = 0.9944408535957336
#
#             Precision = 0.5531145334243774
#
#             Recall = 0.7843217253684998
#
#             F1-Score = 0.6487333178520203
#
#             mIoU = 0.7372524738311768
#
# [Epoch 197]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.89s/it, loss=0.0401]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.92s/it, loss=0.0466]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5212515/5242880 correct pixels, with TP = 28185, TN = 5184330, FP = 24235, FN = 6130.
#
# Metric scores: Accuracy = 0.9942083358764648
#
#             Precision = 0.5376764535903931
#
#             Recall = 0.8213609457015991
#
#             F1-Score = 0.6499106287956238
#
#             mIoU = 0.7377802133560181
#
# [Epoch 198]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.91s/it, loss=0.0406]
# 100%|████████████████████████████████| 7/7 [00:21<00:00,  3.04s/it, loss=0.0488]
#   0%|                                                     | 0/7 [00:00<?, ?it/s]
#
# Got 5213742/5242880 correct pixels, with TP = 28102, TN = 5185640, FP = 22925, FN = 6213.
#
# Metric scores: Accuracy = 0.9944424033164978
#
#             Precision = 0.5507280230522156
#
#             Recall = 0.818942129611969
#
#             F1-Score = 0.6585737466812134
#
#             mIoU = 0.7426813840866089
#
# [Epoch 199]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.97s/it, loss=0.0457]
# 100%|████████████████████████████████| 7/7 [00:20<00:00,  2.87s/it, loss=0.0394]
#
# => Saving checkpoint at epoch 200.
#
#
# Got 5214795/5242880 correct pixels, with TP = 27476, TN = 5187319, FP = 21246, FN = 6839.
# => Saving best miou checkpoint.
# => Saving best f1_score checkpoint.
#
# Metric scores: Accuracy = 0.9946432113647461
#
#             Precision = 0.5639341473579407
#
#             Recall = 0.8006994128227234
#
#             F1-Score = 0.6617772579193115
#
#             mIoU = 0.7445672750473022
